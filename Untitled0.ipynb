# %%
PATH = "/content/drive/My Drive/67842 Introduction to Artificial Intelligence/Blockudoku-ai"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
sys.path.append(PATH)

# %%
import importlib
import q_learning_agent
import Engine
importlib.reload(q_learning_agent)
importlib.reload(Engine)
# Out:
# True
# updated
# <module 'Engine' from '/content/drive/My Drive/67842 Introduction to Artificial Intelligence/Blockudoku-ai/Engine.py'>

# %%
game = Engine.Blockudoku()
agent = q_learning_agent.QLAgent(game, 1, 0.001, 0.995)
agent.train(1000, 1000, render=False, save=True, save_path=f"{PATH}/colab_model.pth")
# Out:
# ----------------------------------------- episode = 0
# total score = 39
# total reward =  -3146
# last loss = 0.35732772946357727
# saved
# ----------------------------------------- episode = 1
# total score = 16
# total reward =  -1831
# last loss = 0.16112320125102997
# saved
# ----------------------------------------- episode = 2
# total score = 14
# total reward =  -1932
# last loss = 0.12418374419212341
# saved
# ----------------------------------------- episode = 3
# total score = 32
# total reward =  -1760
# last loss = 0.2256450206041336
# saved
# ----------------------------------------- episode = 4
# total score = 13
# total reward =  -1321
# last loss = 0.135478213429451
# saved
# ----------------------------------------- episode = 5
# total score = 7
# total reward =  -1214
# last loss = 0.16959995031356812
# saved
# ----------------------------------------- episode = 6
# total score = 35
# total reward =  -1289
# last loss = 0.022956419736146927
# saved
# ...
